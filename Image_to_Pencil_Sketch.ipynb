# %%
# Import the necessary libraries
import cv2
import matplotlib.pylab as plt

# %%
# Below code reads an image named "Cheetah.jpg" from the "/content" directory using OpenCV.
image = cv2.imread("/content/Cheetah.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=630x360>

# %%
# converts the previously loaded color image to grayscale using OpenCV's BGR-to-Gray conversion.
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=630x360>

# %%
# Invert the pixel values
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=630x360>

# %%
# Apply Gaussian blur with a 5x5 kernel
blurred_image = cv2.GaussianBlur(image, (5, 5), 0)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=RGB size=630x360>

# %%
# Creates a sketch-like image by blending the original grayscale image with an inverted and blurred version using the "color dodge" blending mode
sketch = cv2.divide(gray_image, 255 - blurred_inverted_image, scale=256)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=630x360>
